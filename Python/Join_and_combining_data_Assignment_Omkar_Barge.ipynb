# %%
import numpy as np
import pandas as pd

# %%
student_data1 = pd.DataFrame({'student_id' : ['S1','S2','S3','S4','S5'],
                              'name' : ['Danniella Fenton','Ryder Storey','Bryce Jensen','Ed Bernal','Kwame Morin'],
                              'marks': [200,210,190,222,199]})

# %%
student_data1
# Out:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199

# %%
student_data2 = pd.DataFrame({'student_id' : ['S4','S5','S6','S7','S8'],
                              'name' : ['Scarlette Fisher','Carla Williamson','Dante Morse','Kaiser William','Madeeha Preston'],
                              'marks': [201,200,198,219,201]})

# %%
student_data2
# Out:
#   student_id              name  marks
# 0         S4  Scarlette Fisher    201
# 1         S5  Carla Williamson    200
# 2         S6       Dante Morse    198
# 3         S7    Kaiser William    219
# 4         S8   Madeeha Preston    201

# %%
# 1.Write a Pandas program to join the two given dataframes along rows and assign all data.

j1 = pd.concat([student_data1,student_data2],axis=0)
j1
# Out:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199
# 0         S4  Scarlette Fisher    201
# 1         S5  Carla Williamson    200
# 2         S6       Dante Morse    198
# 3         S7    Kaiser William    219
# 4         S8   Madeeha Preston    201

# %%
exam_data = pd.DataFrame({'student_id' : ['S1','S2','S3','S4','S5','S7','S8','S9','S10','S11','S12','S13'],
              'exam_id' : [23,45,12,67,21,55,33,14,56,83,88,12]})

# %%
# 2.Write a Pandas program to join the two given dataframes along rows and merge with another dataframe along the common column id.
df_student = student_data1.append(student_data2)

merge_col = pd.merge(df_student,exam_data,on='student_id',how = 'inner')

merge_col
# Out:
#   student_id              name  marks  exam_id
# 0         S1  Danniella Fenton    200       23
# 1         S2      Ryder Storey    210       45
# 2         S3      Bryce Jensen    190       12
# 3         S4         Ed Bernal    222       67
# 4         S4  Scarlette Fisher    201       67
# 5         S5       Kwame Morin    199       21
# 6         S5  Carla Williamson    200       21
# 7         S7    Kaiser William    219       55
# 8         S8   Madeeha Preston    201       33

# %%
df_matches = pd.read_csv('/content/matches.csv')

# %%
# 3.Split the dataset into 2 parts,first containing top 5 rows and the other containing next 5 rows.
# Print the shape and then append the 1st dataframe to the end of the 2nd dataframe.

top5 = df_matches.iloc[:5,:]
last5 = df_matches.iloc[5:10,:]

print(top5.shape)
print(last5.shape)
# Out:
# (5, 18)
# (5, 18)

# %%
col_app = top5.append(last5)
col_app
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
# 4.Split the dataset in to 2 parts,first containing top 5 rows and the other containing next 5 rows.Print the shape and then concat them based on columns.
top5 = df_matches.iloc[:5,:]
last5 = df_matches.iloc[5:10,:]

print(top5.shape)
print(last5.shape)
# Out:
# (5, 18)
# (5, 18)

# %%
col_con = pd.concat([top5,last5],axis=1)
col_con
# Out:
#     id  season       city        date                        team1  \
# 0  1.0  2017.0  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1  2.0  2017.0       Pune  2017-04-06               Mumbai Indians
# 2  3.0  2017.0     Rajkot  2017-04-07                Gujarat Lions
# 3  4.0  2017.0     Indore  2017-04-08       Rising Pune Supergiant
# 4  5.0  2017.0  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5  NaN     NaN        NaN         NaN                          NaN
# 6  NaN     NaN        NaN         NaN                          NaN
# 7  NaN     NaN        NaN         NaN                          NaN
# 8  NaN     NaN        NaN         NaN                          NaN
# 9  NaN     NaN        NaN         NaN                          NaN
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
# 5.Split the dataset into 2 parts based on the columns,print their shape and then join them with the columns of 1st dataframe being displayed after the columns of 2nd dataframe.
top5_col = df_matches.iloc[:,:5]
last5_col = df_matches.iloc[:,5:10]

print(top5_col.shape)
print(last5_col.shape)
# Out:
# (636, 5)
# (636, 5)

# %%
col_join = top5_col.join(last5_col)
col_join
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...
